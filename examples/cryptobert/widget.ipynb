# %%
from saefarer.widget import Widget, WidgetConfig

# %%
cfg = WidgetConfig(height=750, base_font_size=16, n_table_rows=10)

# %%
w = Widget(
    path="analysis.db",
    cfg=cfg,
)

w
# Out:
# Widget(base_font_size=16, detail_feature={'sae_id': 'default', 'feature_id': 3071, 'max_act': 6.93680906295776…
